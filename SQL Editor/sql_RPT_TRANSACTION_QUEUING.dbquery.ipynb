-- %%
CREATE TABLE IF NOT EXISTS RPT_TRANSACTION_QUEUING (
    TXN_DT TIMESTAMP COMMENT 'Ngày giao dịch',
    CNC2_CODE STRING COMMENT 'Mã CN C2',
    CNC2_NAME STRING COMMENT 'Tên CN C2',
    CNC1_CODE STRING COMMENT 'Mã CN C1',
    CNC1_NAME STRING COMMENT 'Tên CN C1',
    TICKET_NBR STRING COMMENT 'Số phiếu',
    CST_CODE STRING COMMENT 'Code KH',
    CST_NM STRING COMMENT 'Tên khách hàng',
    TXN_TP STRING COMMENT 'Loại giao dịch',
    CST_SEG STRING COMMENT 'Phân khúc KH',
    TXN_NM STRING COMMENT 'Giao dịch',
    TTL_NM STRING COMMENT 'Chức danh',
    SRV_USR_ID STRING COMMENT 'User phục vụ',
    SRV_USR_NM STRING COMMENT 'Tên user phục vụ',
    SRV_STALL INT COMMENT 'Quầy phục vụ',
    TICKET_TIME_SLOT STRING COMMENT 'Khung giờ lấy phiếu',
    TICKET_TIME TIMESTAMP COMMENT 'Thời gian lấy phiếu',
    START_SRV_TIME TIMESTAMP COMMENT 'Thời gian bắt đầu phục vụ',
    END_TXN_TIME TIMESTAMP COMMENT 'Thời gian kết thúc giao dịch',
    TOTAL_WAIT_TIME DECIMAL(10,2) COMMENT 'Tổng thời gian chờ',
    SRV_DURATION DECIMAL(10,2) COMMENT 'Thời gian phục vụ',
    END_STATUS STRING COMMENT 'Trạng thái kết thúc',
    REMARK STRING COMMENT 'Ghi chú',
    BOOKING_TICKET STRING COMMENT 'Phiếu booking',
    TRANSFER_TICKET STRING COMMENT 'Phiếu chuyển quầy',
    TICKET_FLOW STRING COMMENT 'Luồng lấy phiếu',
    MY_MB_APP_FLOW STRING COMMENT 'Luồng App My MB'
)
USING DELTA
COMMENT 'Bảng chi tiết giao dịch tại quầy và điều phối luồng khách hàng';
