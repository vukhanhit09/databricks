-- %%
--select distinct month(`CDR_DT`) from mb_poc.gold.rpt_nhs_d01_smy 

select count(1) from mb_poc.gold.rpt_khcn_hdv_d09_dgtal_svg
--delete from mb_poc.gold.rpt_khcn_hdv_d09_dgtal_svg 


SELECT * FROM rpt_nhs_d01_smy where `CDR_DT` >= '2025-12-25'
