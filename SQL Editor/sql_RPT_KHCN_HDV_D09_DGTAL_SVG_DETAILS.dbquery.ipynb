-- %%
CREATE TABLE IF NOT EXISTS RPT_KHCN_HDV_D09_DGTAL_SVG_DETAILS (
    -- Địa lý và Thời gian (Geography & Time)
    SUB_RGON STRING COMMENT 'Tiểu Vùng',
    CDR_DT DATE COMMENT 'Tháng báo cáo',
    
    -- Thông tin đơn vị (Organizational Unit Info)
    MA_CNC1 STRING COMMENT 'Mã chi nhánh cấp 1',
    TEN_CNC1 STRING COMMENT 'Tên chi nhánh cấp 1',
    MA_CNC2 STRING COMMENT 'Mã chi nhánh cấp 2',
    TEN_CNC2 STRING COMMENT 'Tên chi nhánh cấp 2',
    
    -- Thông tin nhân viên quản lý (RM/LLB Info)
    RM_CODE STRING COMMENT 'Mã LLB (Relationship Manager Code)',
    RM_NM STRING COMMENT 'Tên LLB (Relationship Manager Name)',
    TTL_NM STRING COMMENT 'Chức danh',
    
    -- Chỉ số tổng hợp trong tháng (MTD Metrics)
    NBR_OF_NEW_AC_MTD INT COMMENT 'Số lượng sổ mở mới',
    NEW_OPN_TVR_MTD DECIMAL(38,8) COMMENT 'Doanh số mở mới',
    
    -- Chi tiết doanh số theo loại sản phẩm và lãi suất (Product & Rate Details)
    SP_SO_LS_THUONG DECIMAL(38,8) COMMENT 'Doanh số SP số LS theo biểu',
    SP_SO_LS_VOUCHER DECIMAL(38,8) COMMENT 'Doanh số SP số LS cộng voucher',
    SP_QUAY_LS_THUONG DECIMAL(38,8) COMMENT 'Doanh số SP quầy LS theo biểu',
    SP_QUAY_LS_VOUCHER DECIMAL(38,8) COMMENT 'Doanh số SP quầy LS cộng hotline'
)
USING DELTA
PARTITIONED BY (CDR_DT)
COMMENT 'Báo cáo chi tiết doanh số huy động vốn kỹ thuật số và tại quầy theo nhân viên (LLB) và đơn vị kinh doanh';
